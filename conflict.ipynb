# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(10, 20, size=20)
y = np.random.rand(20)
print(x)
print(y)
# Out:
# [12 12 14 18 18 16 19 18 11 15 15 17 12 13 16 11 13 14 15 17]
# [0.44143553 0.48290196 0.81835698 0.84419404 0.81152875 0.16910829
#  0.37548433 0.65763267 0.4300524  0.08469487 0.25050767 0.84903822
#  0.49748672 0.01196959 0.46581445 0.61597347 0.19712796 0.82362475
#  0.98347414 0.95110306]

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
fig, ax = plt.subplots()

ax.plot(x, y, label="XY")
ax.set_title("XY LinePlot")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,5))       # note the s at the end

ax.bar(x, y, label="XY", color = 'orange')
ax.set_title("XY Bargraph")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.legend()
plt.show()
